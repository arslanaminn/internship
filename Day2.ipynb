# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img=cv2.imreadimg = cv2.imread("colofulpic.jpg")

# %%
plt.imshow(img)

# %%
img.shape
# Out:
# (678, 960, 3)

# %%
new_img = cv2.resize(img, (1000,1000))

# %%
img.shape
# Out:
# (678, 960, 3)

# %%
plt.imshow(new_img)

# %%
#red_ch = new_img[:,:,0]
#grn_ch = new_img[:,:,1]
#blu_ch = new_img[:,:,2]

# %%
r,g,b = cv2.split(new_img)

# %%
black = cv2.merge([r*0, g*0, b*0])

# %%
plt.imshow(black)

# %%
 black[:] = [255,255,255]

# %%
plt.imshow(black)

# %%
h, w, c=black.shape

# %%
copy2_img = black.copy()

# %%
copy2_img.shape
# Out:
# (1000, 1000, 3)

# %%
print(h, w)
# Out:
# 1000 1000

# %%
for i in range(0, h):
    for j in range(0,w):
        if i%200==0:
            copy2_img[i,j,:] = (255,0,0)
        if j%200==0:
            copy2_img[i,j,:] = (0,0,255)
            
plt.figure(figsize=(30,30))
plt.imshow(copy2_img)

# %%
aa = 200%200

# %%
aa
# Out:
# 0

# %%
10%2
# Out:
# 0

# %%
#plt.imshow(red_grn_ch)

# %%
#grn_ch[:5,:5]

# %%
#plt.imshow(grn_ch)

# %%
#plt.imshow(blu_ch)
